# %%
import pandas as pd
import tensorflow as tf
from glob import glob
import numpy as np
from easydict import EasyDict as edict
import os
import time
import sys
from tabulate import tabulate

sys.path.insert(0,os.path.expanduser('~/git/torchseg'))
print(sys.path)

from utils.config import load_config
from utils.summary_to_csv import config_to_log,edict_to_pandas

def summary(rootpath,tags,filter_str=None,):
    config_files=glob(os.path.join(rootpath,'**','config.txt'),recursive=True)
    for f in config_files:
        print(f)
    if filter_str is not None:
        config_files=[f for f in config_files if f.find(filter_str)>=0]
    for f in config_files:
        print(f)
        
    tasks=pd.DataFrame()
    for cfg in config_files:
        log=config_to_log(cfg)
        if log is not None:
            ed=load_config(cfg)
            try:
                metrics=load_log(log,tags)
            except:
                print('log %s is truncated'%log)
                return tasks
            
            for key,value in metrics.items():
                ed[key]=value
            ed['dir']=cfg
            task=edict_to_pandas(ed)
            tasks=tasks.append(task,ignore_index=True,sort=False)
        else:
            print('cannot find log file for',cfg)
            
    return tasks

rootpath=os.path.expanduser('~/tmp/logs/cdnet2014')
tags=['fmeasure','val_fmeasure']
notes=['MotionNet_V3','MotionNet3_light','TwoStream','OneStream']
note_gtags=[['trainable_ratio','split_mode'],
            ['trainable_ratio','split_mode'],
           ['trainable_ratio','split_mode'],
           ['trainable_ratio','split_mode']]
describe=[]

dir_tags=[tags[1],'dir']
for note,ntag in zip(notes,note_gtags):
    show_tags=[]
    show_tags=tags.copy()
    group_tags=['note']+ntag
    show_tags+=group_tags
    show_tags+=['epoches']
    tasks=summary(rootpath,tags,note)
    if tasks.empty:
        print(note,ntag,'task is empty')
        continue
        
    #print(tasks[show_tags].groupby(group_tags).max().to_string())
    print(tabulate(tasks[show_tags].groupby(group_tags).mean().sort_values(tags[1]),tablefmt='pipe',headers='keys'))
    print('\n')
    print(tabulate(tasks[[tags[1]]+group_tags].groupby(group_tags).agg([np.mean,np.std,np.max]),tablefmt='pipe',headers='keys'))
    print('\n')
    print(tabulate(tasks[show_tags].sort_values(tags[1]),tablefmt='pipe',headers='keys'))
    print('\n')
    print(tabulate(tasks[dir_tags].sort_values(tags[1]),tablefmt='pipe',headers='keys'))
    print('\n')
# Out:
# ['/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '/home/yzbx/git/torchseg', '', '/home/yzbx/git/torchseg/notebooks', '/home/yzbx/git/gnu/models/research', '/home/yzbx/git/gnu/models/research/slim', '/home/yzbx/bin/miniconda3/envs/new/lib/python36.zip', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6/lib-dynload', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6/site-packages', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6/site-packages/cityscapesscripts-1.0.0-py3.6-linux-x86_64.egg', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg', '/home/yzbx/bin/miniconda3/envs/new/lib/python3.6/site-packages/IPython/extensions', '/home/yzbx/.ipython']
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-59-19/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-56-47/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___17-01-14/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp2/2018-05-02___20-51-13/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp2/2018-05-03___06-02-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp2/2018-05-03___01-22-56/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp/2018-05-01___02-05-40/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp/2018-04-30___21-22-50/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt
# |                             |   fmeasure |   val_fmeasure |   epoches |
# |:----------------------------|-----------:|---------------:|----------:|
# | ('v3', 0.5, 'sub_category') |   0.921674 |       0.423909 |       100 |
#
#
# |                             |   ('val_fmeasure', 'mean') |   ('val_fmeasure', 'std') |   ('val_fmeasure', 'amax') |
# |:----------------------------|---------------------------:|--------------------------:|---------------------------:|
# | ('v3', 0.5, 'sub_category') |                   0.423909 |                  0.106471 |                   0.499195 |
#
#
# |    |   fmeasure |   val_fmeasure | note   |   trainable_ratio | split_mode   |   epoches |
# |---:|-----------:|---------------:|:-------|------------------:|:-------------|----------:|
# |  1 |   0.908432 |       0.348623 | v3     |               0.5 | sub_category |       100 |
# |  0 |   0.934916 |       0.499195 | v3     |               0.5 | sub_category |       100 |
#
#
# |    |   val_fmeasure | dir                                                                            |
# |---:|---------------:|:-------------------------------------------------------------------------------|
# |  1 |       0.348623 | /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt |
# |  0 |       0.499195 | /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt |
#
#
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-59-19/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-56-47/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___17-01-14/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp2/2018-05-02___20-51-13/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp2/2018-05-03___06-02-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp2/2018-05-03___01-22-56/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp/2018-05-01___02-05-40/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp/2018-04-30___21-22-50/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/config.txt
# log /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/events.out.tfevents.1551409704.dp is truncated
# MotionNet3_light ['trainable_ratio', 'split_mode'] task is empty
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-59-19/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-56-47/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___17-01-14/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp2/2018-05-02___20-51-13/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp2/2018-05-03___06-02-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp2/2018-05-03___01-22-56/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp/2018-05-01___02-05-40/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp/2018-04-30___21-22-50/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/config.txt
# TwoStream ['trainable_ratio', 'split_mode'] task is empty
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-59-19/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___16-56-47/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp/2018-04-30___17-01-14/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.1_imgnet_pp2/2018-05-02___20-51-13/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp2/2018-05-03___06-02-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp2/2018-05-03___01-22-56/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.9_imgnet_pp/2018-05-01___02-05-40/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_TwoOutput/one_mask_category_train_ratio_0.5_imgnet_pp/2018-04-30___21-22-50/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___11-28-17/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet_V3/v3/2019-03-01___00-29-49/config.txt
# /home/yzbx/tmp/logs/cdnet2014/MotionNet3_light/v3/2019-03-01___11-08-11/config.txt
# OneStream ['trainable_ratio', 'split_mode'] task is empty
